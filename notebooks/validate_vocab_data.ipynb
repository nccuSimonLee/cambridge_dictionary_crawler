# %%
import json

# %%
with open('../ScrambleDict/cambridge.word.888.json', 'r') as f:
    now_data = json.load(f)

with open('/home/old/fun/crawling-cambridge-dictionary/cambridge.word.666.json', 'r') as f:
    pre_data = json.load(f)

# %%
with open('../ScrambleDict/vocab_data.json', 'r') as f:
    vocab_data = json.load(f)

# %%
vocab_data_dict = {}
for vd in vocab_data:
    vocab, data = list(vd.items())[0]
    vocab_data_dict[vocab] = data

# %%
pre_data['fiancé']
# Out:
# {'noun': [{'sense': [{'en_def': 'the man who someone is engaged to be married to',
#      'ch_def': '未婚夫',
#      'level': 'none',
#      'examples': ["Have you met Christina's fiancé?", '你見過克莉絲蒂娜的未婚夫嗎？'],
#      'gcs': ''}],
#    'extra_sents': [],
#    'guideword': ''}]}

# %%
now_data['micro']['prefix']
# Out:
# [{'guideword': '(SMALL)',
#   'sense': [{'en_def': 'very small',
#     'ch_def': '小的，微小的',
#     'level': '',
#     'examples': [{'en': 'a microorganism', 'ch': '微生物'},
#      {'en': 'microbiology', 'ch': '微生物學'}]}],
#   'phrase': [],
#   'extra_sents': []},
#  {'guideword': '(MEASUREMENT)',
#   'sense': [{'en_def': '0.000 001 or one millionth of the stated unit',
#     'ch_def': '微，百萬分之一',
#     'level': '',
#     'examples': [{'en': 'a micrometre', 'ch': '微米'},
#      {'en': 'a microgram', 'ch': '微克'}]}],
#   'phrase': [],
#   'extra_sents': []}]

# %%
pre_data['micro']
# Out:
# {'noun': [{'sense': [{'en_def': 'informal for\nmicrocomputer',
#      'ch_def': '微型電腦（microcomputer的非正式说法）',
#      'level': 'none',
#      'examples': [],
#      'gcs': ''}],
#    'extra_sents': [],
#    'guideword': ''}]}

# %%
pre_data['micro-']
# Out:
# {'prefix': [{'sense': [{'en_def': 'very small',
#      'ch_def': '小的，微小的',
#      'level': 'none',
#      'examples': ['a microorganism', '微生物', 'microbiology', '微生物學'],
#      'gcs': ''}],
#    'extra_sents': [],
#    'guideword': '(SMALL)'},
#   {'sense': [{'en_def': '0.000 001 or one millionth of the stated unit',
#      'ch_def': '微，百萬分之一',
#      'level': 'none',
#      'examples': ['a micrometre', '微米', 'a microgram', '微克'],
#      'gcs': ''}],
#    'extra_sents': [],
#    'guideword': '(MEASUREMENT)'}]}

# %%
pre_data['fianc']

# %%
len(now_data)
# Out:
# 44514

# %%
len(pre_data)
# Out:
# 30746

# %%
set(pre_data.keys()).difference(now_data.keys())
# Out:
# {'Honduras',
#  'fiancé',
#  'colón',
#  'PLO',
#  'Excellency',
#  'Burundi',
#  'Balkan',
#  'DRM',
#  'Cinderella',
#  'Malay',
#  'VDT',
#  'Yiddish',
#  'a.m.',
#  '-filled',
#  'BS',
#  '-time',
#  'SARS',
#  '-mania',
#  'Carousel',
#  'MBE',
#  'IgM',
#  'Blighty',
#  'touché',
#  'Namibia',
#  'Nigeria',
#  'COBOL',
#  'ABC',
#  'Rwanda',
#  'BFF',
#  'Gabonese',
#  'café',
#  'LLB',
#  'GPRS',
#  'Footsie',
#  'OTT',
#  'techno-',
#  'Christendom',
#  'Majesty',
#  'the Premiership',
#  'Chicano',
#  'Ecuador',
#  'Corinthian',
#  'lycée',
#  'Sen.',
#  'Australasia',
#  'CABG',
#  'Ebonics',
#  'Chinese',
#  'Batswana',
#  'EHF',
#  '-capable',
#  'the Creed',
#  'QA',
#  '-wise',
#  'Judaic',
#  'Myanmar',
#  'Britishness',
#  'Switzerland',
#  'Vietnamese',
#  'Belgium',
#  'Mormon',
#  '-grained',
#  'Welsh',
#  'Siberian',
#  '-rage',
#  'the Bill',
#  '-an',
#  'Pakistani',
#  'CE',
#  'Laos',
#  'Bakelite',
#  'Rubicon',
#  'Americanism',
#  'OCR',
#  'Hispanic',
#  'MRI',
#  'Lt',
#  'Berber',
#  '-celled',
#  'USP',
#  'Msgr',
#  'née',
#  'Australasian',
#  'WPC',
#  'Lisp',
#  'Barbadian',
#  'Olympian',
#  'Aryan',
#  'the Met',
#  'Kalashnikov',
#  'Sr.',
#  'Mexico',
#  'Impressionism',
#  'Chilean',
#  'Madagascar',
#  'the TA',
#  'Taser',
#  'Entryphone',
#  '-breaker',
#  'GSM',
#  'tele-',
#  'Maltese',
#  'HBV',
#  'Interpol',
#  'soigné',
#  'Lady',
#  'Fijian',
#  'IELTS',
#  'Frankenstein',
#  'CONMEBOL',
#  'Venus',
#  'China',
#  '-saver',
#  'Congo',
#  'Iraqi',
#  'Kitemark',
#  'YouTube',
#  '-going',
#  '-esque',
#  '-faceted',
#  'Chardonnay',
#  'VAS',
#  'Singapore',
#  'Lucite',
#  'PTSD',
#  'Azeri',
#  '-petalled',
#  '-ism',
#  'Ben',
#  'Machiavellian',
#  'Jesuit',
#  'Shakespearean',
#  'Stetson',
#  'Chartreuse',
#  'Dominica',
#  'Slovenia',
#  'cont.',
#  'Urdu',
#  '-armed',
#  'VIP',
#  '-hearted',
#  '-ful',
#  'ME',
#  'Pacific',
#  'Miss',
#  'TESSA',
#  'Kuwaiti',
#  'Bros.',
#  'Hindu',
#  'exposé',
#  'Derby',
#  'Menshevik',
#  'GNI',
#  'Pty',
#  'Poland',
#  'Labour',
#  'ADD',
#  'Punjabi',
#  '-ability',
#  'Saxon',
#  'Germany',
#  'BM',
#  'Ugandan',
#  'EMS',
#  'Eid',
#  'Tunisian',
#  'October',
#  'Franciscan',
#  'Arcadia',
#  'Comoros',
#  'Malagasy',
#  'Djiboutian',
#  'RAM',
#  'Irish',
#  'Tibetan',
#  '-ish',
#  'Hebrew',
#  'Friday',
#  'PDC',
#  'Yankee',
#  '-ics',
#  'SS',
#  'Kazakh',
#  'Nicaragua',
#  'mal-',
#  'Nigerian',
#  'Maori',
#  'SI',
#  'PowerPoint',
#  'Stilton',
#  'Dec.',
#  'purée',
#  'Britain',
#  'BC',
#  'HFC',
#  'Suriname',
#  'en-',
#  'AMD',
#  'Indonesian',
#  'COD',
#  'Muhammad',
#  'hecto-',
#  'micro-',
#  'centi-',
#  'cardio-',
#  '-wallah',
#  'Paddy',
#  'Angola',
#  '-made',
#  'Quebec',
#  'Orcadian',
#  'Facebook',
#  'NutraSweet',
#  'Basque',
#  '-bodied',
#  'SAM',
#  'A',
#  '-haired',
#  'IPA',
#  'the MOD',
#  'Norman',
#  'Pangaea',
#  'MWA',
#  'Viagra',
#  'HMP',
#  'Gibraltar',
#  'exa-',
#  '-ways',
#  'Monday',
#  'Babygro',
#  'Ansaphone',
#  'PCB',
#  'col.',
#  'ITV',
#  'Rastafarian',
#  'Abrahamic',
#  'Jupiter',
#  'ASEAN',
#  'açaí',
#  'Corp.',
#  'passé',
#  'WAP',
#  'röntgen',
#  'TEFL',
#  'EVD',
#  'Muscovite',
#  '-ware',
#  'NiCad',
#  '-wheeler',
#  '-mate',
#  'Oman',
#  'Caribbean',
#  'Greater',
#  'cliché',
#  'Prohibition',
#  'Marian',
#  'Krishna',
#  'Venezuela',
#  'Oxon',
#  'Teutonic',
#  'CBT',
#  'the Almighty',
#  'toupée',
#  'PSC',
#  'Lucifer',
#  'Shabbat',
#  'Bermudan',
#  'outré',
#  'Stradivarius',
#  'CID',
#  'Lurex',
#  'Palau',
#  'Garda',
#  'Damocles',
#  'Quorn',
#  'Eurocheque',
#  'Teletext',
#  'Romance',
#  '-toned',
#  'Freefone',
#  'IVF',
#  'Th',
#  'Jewry',
#  '-able',
#  'Angrez',
#  'Mauritania',
#  'curaçao',
#  'GNP',
#  'SMTP',
#  'tera-',
#  'Zaire',
#  'Jordan',
#  'Freemasonry',
#  'semi-',
#  'PPS',
#  'MTV',
#  'C++',
#  'col-',
#  'Communion',
#  'Pharisee',
#  'Gemini',
#  'the Renaissance',
#  'the Resurrection',
#  'HOV',
#  'UTI',
#  'Eucharist',
#  'Realtor',
#  'Regency',
#  'IMAX',
#  'cybercafé',
#  'Green',
#  'Olympiad',
#  'Icelander',
#  'Burma',
#  'Lilliputian',
#  'HSC',
#  'Belizean',
#  'A3',
#  'SSRI',
#  '-gauge',
#  'Catholic',
#  'éclair',
#  'QC',
#  'Taoiseach',
#  'Afghan',
#  'Iran',
#  'Melanesian',
#  'Persian',
#  'Frenchman',
#  'BEd',
#  'Chad',
#  '-legged',
#  'Tahitian',
#  'Negress',
#  '-cornered',
#  "'n'",
#  '-ship',
#  'Saturn',
#  'NATO',
#  'Stygian',
#  'Macedonia',
#  'Singaporean',
#  'Austria',
#  'shorthold ',
#  'MPV',
#  '-water',
#  'Keynesian',
#  'Honduran',
#  '-buster',
#  'RSS',
#  'con-',
#  'DIY',
#  'Belgian',
#  'Teflon',
#  'béchamel',
#  'Cistercian',
#  'API',
#  'pre-',
#  'Taiwanese',
#  'VHF',
#  'A4',
#  '-bearing',
#  'viz.',
#  'Erse',
#  'ICBM',
#  'Oxfam',
#  'Israelite',
#  'Plasticine',
#  'Benedictine',
#  'CKD',
#  'Col.',
#  'Inc.',
#  'Oxbridge',
#  'Parmesan',
#  'para-',
#  'VoIP',
#  'Australia',
#  'Japanese',
#  'WC',
#  'NASCAR',
#  'Triassic',
#  'long.',
#  'LMS',
#  'CRT',
#  '-breasted',
#  '-odd',
#  'Malawi',
#  'EPG',
#  'Panama',
#  'negligée',
#  '-penny',
#  'VEGF',
#  'FMV',
#  'Buddhism',
#  'ROM',
#  'Jamaica',
#  'cert.',
#  'Hummer',
#  'Mace',
#  '-ibility',
#  'IV',
#  'out-',
#  'MSG',
#  'masc.',
#  'PAC',
#  'LGBT',
#  'Romany',
#  '-eyed',
#  'Ebola',
#  'Grenada',
#  'RP',
#  'IgG',
#  'Christmas',
#  'Dr',
#  'Cyrillic',
#  'Leninism',
#  'Belize',
#  '-sexed',
#  '-textured',
#  '-free',
#  'LW',
#  '-seeded',
#  'Mini',
#  'über-',
#  'Holiness',
#  '-stained',
#  'Farsi',
#  'Cypriot',
#  'Neogene',
#  'Somali',
#  'Britannic',
#  'Seychellois',
#  '-flavoured',
#  'Bolivia',
#  'Martian',
#  'tRNA',
#  'Freudian',
#  '-driven',
#  'Jehovah',
#  'LPN',
#  'Scout',
#  'Sasquatch',
#  'min.',
#  '-based',
#  'Ionic',
#  'Luxembourger',
#  '-scape',
#  'Chinky',
#  'Valium',
#  'Humvee',
#  'ATM',
#  'Nicaraguan',
#  'SIDS',
#  'CUS',
#  'Strimmer',
#  'Afro-',
#  'Honorable',
#  'milli-',
#  'POW',
#  'GUI',
#  'Olestra',
#  'no.',
#  'pg.',
#  'Britisher',
#  '-born',
#  'Advent',
#  'the Creation',
#  'neo-',
#  'Azerbaijani',
#  'Romanticism',
#  'Hb',
#  'mis-',
#  'SCC',
#  'ibid.',
#  'Colombian',
#  'BL',
#  'Merc',
#  'ill-',
#  'Vanuatuan',
#  'Jacobean',
#  'Saudi',
#  'façade',
#  'Angostura',
#  'Shah',
#  'Halloween',
#  'Cellophane',
#  'Salvadorean',
#  'Mongolia',
#  '-ative',
#  'Bantu',
#  'Latvian',
#  'Wagnerian',
#  'Yardie',
#  'Prof.',
#  'épée',
#  'Libra',
#  'Portuguese',
#  'Taffy',
#  'Photoshop',
#  'Gentile',
#  'Serbia',
#  'Gaelic',
#  'Tamil',
#  'Afrikaans',
#  'Impressionist',
#  'Doric',
#  'sub-',
#  'Dumpster',
#  'Jr.',
#  '-ward',
#  'Liechtensteiner',
#  'Ireland',
#  'cross-',
#  'GED',
#  'the Bar',
#  'Gothic',
#  'HMO',
#  'Mandarin',
#  'WBC',
#  'Spaniard',
#  'paleo-',
#  'Prosecco',
#  'Democrat',
#  'Tunisia',
#  'Moorish',
#  'Calvinist',
#  'Technicolor',
#  'the Pentagon',
#  'Turkey',
#  'MILF',
#  '-grader',
#  '-ency',
#  'Levantine',
#  'Popsicle',
#  'BST',
#  'Romanesque',
#  'MA',
#  'Sagittarius',
#  '-head',
#  '-tasting',
#  'MO',
#  'ingénue',
#  'Gallic',
#  'Paralympian',
#  'Oz',
#  'it-',
#  'Scouse',
#  'Trinidadian',
#  'Slavic',
#  'Nauru',
#  'Bhutan',
#  'CGI',
#  'Armenia',
#  'Englishwoman',
#  'Speedos',
#  'ALS',
#  'Bangladeshi',
#  'Genesis',
#  'MC',
#  'Philistine',
#  'Cantonese',
#  'Afro',
#  'Maoism',
#  'N',
#  'Protestant',
#  'the Creator',
#  'GHQ',
#  'RPI',
#  'great-',
#  'Bengali',
#  'SCART',
#  'IPO',
#  'Swede',
#  'Uruguay',
#  'Bob',
#  'Vantage',
#  'Episcopalian',
#  '-work',
#  'Montserratian',
#  'Herculean',
#  'Macedonian',
#  'Italy',
#  'FDG',
#  'Aborigine',
#  'BASIC',
#  'Uranus',
#  'Nordic',
#  'Mediterranean',
#  'the Crucifixion',
#  'NEET',
#  'Sikh',
#  'Fri.',
#  'Norwegian',
#  'Allah',
#  '-headed',
#  'Luso-',
#  '-ical',
#  'ante-',
#  'Cambodian',
#  'Paraguay',
#  'KB',
#  'Esperanto',
#  'Sotho',
#  'Transit',
#  'Sunday',
#  'PhD',
#  'VATable',
#  'Colombia',
#  'Mali',
#  'Blairite',
#  'PE',
#  'the Opposition',
#  '-y',
#  'NAACP',
#  'DDT',
#  'Castilian',
#  'Hoover',
#  'DA',
#  'CD',
#  'CT',
#  'Bulgarian',
#  'under-',
#  'HUD',
#  'Freepost',
#  'cor-',
#  '-ment',
#  'Albanian',
#  'PBS',
#  'Scottie',
#  'SPECT',
#  'step-',
#  'GCF',
#  'PMT',
#  'CPU',
#  'IUD',
#  'God',
#  'Luddite',
#  'Hellenic',
#  'Algerian',
#  'Alaska',
#  'PDQ',
#  'Graeco-',
#  '-fold',
#  'TESL',
#  'ESL',
#  '-ence',
#  'Micronesian',
#  'Vegeburger',
#  'Turkish',
#  '-engined',
#  'Marshallese',
#  'HDTV',
#  'Palestine',
#  'OJ',
#  'Manx',
#  '-age',
#  'Shiism',
#  'Luxembourg',
#  'CFC',
#  'Tagalog',
#  'Bruneian',
#  'ur-',
#  'Passover',
#  'Filipina',
#  'Uzbek',
#  '-sleeved',
#  'Tuvalu',
#  'GCE',
#  'tel.',
#  'post-',
#  'FEMA',
#  'Jacuzzi',
#  'Polaroid',
#  'Cretaceous',
#  '-coloured',
#  'BLT',
#  '-goer',
#  'CAM',
#  'Iranian',
#  'P2P',
#  'Medicare',
#  'English',
#  'Dutch',
#  'ITP',
#  'ENT',
#  'Gameboy',
#  'OPEC',
#  'Mars',
#  'bio-',
#  'Ltd',
#  'GmbH',
#  'whew!',
#  '-spoken',
#  'Paraguayan',
#  'Africa',
#  'UHF',
#  '-hood',
#  'Sanmarinese',
#  'Gibraltarian',
#  'poly-',
#  'Swedish',
#  'Neanderthal',
#  'Iceland',
#  '-racked',
#  'Marines',
#  'Formica',
#  'BMI',
#  'Finnish',
#  'Panamanian',
#  'LCD',
#  'Cavalier',
#  'Brie',
#  'Bangladesh',
#  '-shooter',
#  'Mumbai',
#  'VC',
#  '-borne',
#  'Vietnam',
#  'the Net',
#  'fore-',
#  'Yugoslav',
#  'NE',
#  'HD',
#  'Argentina',
#  'fig.',
#  'CLIL',
#  'Israeli',
#  'Catalan',
#  'recherché',
#  'Snr',
#  '-shy',
#  '-flavored',
#  'arête',
#  'Mammon',
#  'Arctic',
#  'Op.',
#  'Scrabble',
#  'TCM',
#  'eco-',
#  'EMU',
#  'Honourable',
#  'CND',
#  '-field',
#  'ultra-',
#  'Beemer',
#  'Herzegovina',
#  '-ster',
#  'ESP',
#  '-ing',
#  'Tupperware',
#  'Americana',
#  'Swazi',
#  'MDS',
#  'UKAHN',
#  'Sephardic',
#  'bestir ',
#  'Hellenistic',
#  'Braille',
#  '-powered',
#  'Irishman',
#  'Victoriana',
#  'Ethernet',
#  'Georgia',
#  'nano-',
#  'Alsatian',
#  'Nepalese',
#  'HMSO',
#  'CEO',
#  'Goliath',
#  'March',
#  'the Highlands',
#  'India',
#  'ECE',
#  'OB',
#  'Jordanian',
#  'OAP',
#  'SOS',
#  'Anglo',
#  'meta-',
#  'cardi-',
#  'Greece',
#  'contra-',
#  'Egypt',
#  'FSH',
#  'Muzak',
#  '-bound',
#  'Amerindian',
#  'UNESCO',
#  '-capped',
#  'Zen',
#  'Syrian',
#  'NSFW',
#  'pH',
#  'inter-',
#  '-bedroomed',
#  'French',
#  'Liberian',
#  'est.',
#  'LPG',
#  'HNC',
#  'LV',
#  '-spotter',
#  'Silurian',
#  'Darwinian',
#  'ethno-',
#  'ADSL',
#  'Linux',
#  'Botox',
#  'Mauritanian',
#  'TNT',
#  'Samoan',
#  'Saturday',
#  'Doona',
#  'Qi',
#  '-woman',
#  'MPhil',
#  'DOS',
#  'Semtex',
#  'Kraut',
#  'Evangelist',
#  'must-',
#  'Basotho',
#  'JSA',
#  'Turkmen',
#  '-grabbing',
#  'Ghana',
#  'CPA',
#  'GMT',
#  'Rex',
#  'Liechtenstein',
#  'AI',
#  'Harlequin',
#  '-aholic',
#  'Rambo',
#  'CR',
#  'précis',
#  'NCO',
#  'kilo-',
#  'Nazi',
#  '-mouthed',
#  'Madonna',
#  'Ave',
#  'Sino-',
#  'the US',
#  'Mach',
#  'Guatemala',
#  'PMS',
#  'Abo',
#  'Mephistopheles',
#  '-natured',
#  'Bolshevik',
#  'Tampax',
#  'Eurosceptic',
#  'psycho-',
#  '-ese',
#  'ED',
#  'SF',
#  'pico-',
#  'MDF',
#  'Chinatown',
#  'MBA',
#  'BYOD',
#  'Telemessage',
#  'SUV',
#  'CCS',
#  'FAA',
#  '-led',
#  'over-',
#  'Latina',
#  'Gruyère',
#  'entrée',
#  'Turkmenistan',
#  'DVT',
#  'Kittitian',
#  'NHL',
#  'counter-',
#  'Americano',
#  'Taoism',
#  'Siberia',
#  'ELT',
#  'Malaysian',
#  'mid-',
#  'NMO',
#  'Edam',
#  'pâté',
#  'the Web',
#  'Sahrawi',
#  '-est',
#  'up-',
#  'EBT',
#  'Colt',
#  '-ity',
#  'Pliocene',
#  'Judaism',
#  'STD',
#  'British',
#  'May',
#  'Reverend',
#  'Taurus',
#  'hyper-',
#  'GPA',
#  'Capricorn',
#  'Tylenol',
#  'DSL',
#  'HTML',
#  'Baptist',
#  'proto-',
#  'FAE',
#  'Holland',
#  'Slavonic',
#  'Thai',
#  '-faced',
#  'Ulster',
#  'Hegira',
#  'Grace',
#  '-year',
#  'Methodism',
#  'p.a.',
#  'Gy',
#  'Warfarin',
#  '-fully',
#  'Mark',
#  'Glaswegian',
#  'Mayday',
#  'Gujarati',
#  'garçon',
#  'the Inquisition',
#  'Shiite',
#  '-load',
#  'Siamese',
#  'non-',
#  'MetroCard',
#  'SEO',
#  'Swaziland',
#  'Pilates',
#  'AWOL',
#  '-monger',
#  'Lord',
#  'Labrador',
#  '-dimensional',
#  'FoE',
#  'EKG',
#  'Guards',
#  'ICT',
#  'Regina',
#  '-covered',
#  'consommé',
#  'Hawaiian',
#  'ID',
#  'SRN',
#  'the Messiah',
#  'Senegalese',
#  'Higher',
#  'DVR',
#  'Paki',
#  'Greenlander',
#  '-ance',
#  'Ecuadorian',
#  '-ology',
#  'Kazakhstan',
#  'Mozambican',
#  '-toothed',
#  'Muse',
#  'Bollywood',
#  'PFI',
#  'derrière',
#  'Kyrgyz',
#  'December',
#  'Chink',
#  'communiqué',
#  '-style',
#  'Scot',
#  'WAN',
#  'Austrian',
#  'HGV',
#  'deca-',
#  'PWR',
#  '-ista',
#  'Allied',
#  'Hades',
#  'TV',
#  'Homo',
#  'PDF',
#  'MW',
#  'Danish',
#  'Frisbee',
#  'EEG',
#  'IBS',
#  'Pres.',
#  'ER',
#  'Mongolian',
#  'Christian',
#  '-edged',
#  'PAYE',
#  'GDP',
#  'Apex',
#  'Bhutanese',
#  'Cajun',
#  'Lesotho',
#  'trans-',
#  ...}
