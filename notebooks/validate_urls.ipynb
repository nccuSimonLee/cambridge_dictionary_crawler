# %%
import json

# %%
with open('../extendURLs.txt', 'r') as f:
    extend_urls = eval(f.read())

# %%
len(extend_urls)
# Out:
# 50441

# %%
with open('/home/old/fun/crawling-cambridge-dictionary/cambridge.word.666.json', 'r') as f:
    camb_dict = json.load(f)

# %%
extend_heads = [url.split('/')[-1] for url in extend_urls]

# %%
len(camb_dict)
# Out:
# 30746

# %%
camb_dict['apple']['noun'][0]
# Out:
# {'sense': [{'en_def': 'a round fruit with firm, white flesh and a green, red, or yellow skin',
#    'ch_def': '蘋果',
#    'level': 'A1',
#    'examples': ['to peel an apple',
#     '削蘋果',
#     'apple pie/sauce',
#     '蘋果派／醬',
#     'an apple tree',
#     '蘋果樹'],
#    'gcs': ''}],
#  'extra_sents': ['He was munching on an apple.',
#   'He took a bite out of the apple.',
#   'The apple tree at the bottom of the garden is beginning to blossom.',
#   'Newton reasoned that there must be a force such as gravity, when an apple fell on his head.',
#   'Do you have any cooking apples?'],
#  'guideword': ''}

# %% [markdown]
# ## 新資料多新增的字詞

# %%
set(extend_heads).difference(set(camb_dict.keys()))
# Out:
# {'ticker-tape-parade',
#  'barley-sugar',
#  'asiatic',
#  'talk-the-talk-walk-the-walk',
#  'not-have-a-cat-in-hell-s-chance',
#  'designer-stubble',
#  'cna',
#  'kick-up-a-fuss-row-stink',
#  'britannic',
#  'cruise-ship',
#  'be-just-the-job',
#  'dig-yourself-into-a-hole',
#  'unexplained-gastrointestinal-bleeding',
#  'macular-degeneration',
#  'high-risk',
#  'skid-marks',
#  'screw-sth-up',
#  'lead-up-to-sth',
#  'return-ticket',
#  'wishy-washy',
#  'in-spades',
#  'be-an-artist-professional-etc-to-your-fingertips',
#  'close-sth-down',
#  'push-sb-sth-over',
#  'veterinary-surgeon',
#  'tough-sth-out',
#  'bring-sb-round',
#  'shallow-fry',
#  'throw-sb-a-curve-ball',
#  'get-in-there',
#  'tomato-ketchup',
#  'not-see-the-forest-for-the-trees',
#  'with-the-best-will-in-the-world',
#  'buckle-up',
#  'sail-against-the-wind',
#  'thumb-through-sth',
#  'i-don-t-know',
#  'get-over-yourself',
#  'flag-waving',
#  'mental-health',
#  'wood-stove',
#  'zip-sth-sb-up',
# ...
